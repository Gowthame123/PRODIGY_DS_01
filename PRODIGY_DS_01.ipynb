# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
men = pd.read_csv(r"C:\Users\gowth\Downloads\PRODIGY_internship\dataset\task 1\API_SP.POP.TOTL.MA.IN_DS2_en_csv_v2_16250\API_SP.POP.TOTL.MA.IN_DS2_en_csv_v2_16250.csv")

# %%
men.head()
# Out:
#                   Country Name Country Code    Indicator Name  \
# 0                        Aruba          ABW  Population, male
# 1  Africa Eastern and Southern          AFE  Population, male
# 2                  Afghanistan          AFG  Population, male
# 3   Africa Western and Central          AFW  Population, male
# 4                       Angola          AGO  Population, male
#
#       Indicator Code        1960        1961        1962        1963  \
# 0  SP.POP.TOTL.MA.IN     26995.0     27326.0     27692.0     28027.0
# 1  SP.POP.TOTL.MA.IN  64409521.0  66120634.0  67916448.0  69778027.0
# 2  SP.POP.TOTL.MA.IN   4690245.0   4775684.0   4867111.0   4963703.0
# 3  SP.POP.TOTL.MA.IN  48455513.0  49456062.0  50496568.0  51587717.0
# 4  SP.POP.TOTL.MA.IN   2649099.0   2690647.0   2721244.0   2752564.0
#
#          1964        1965  ...         2014         2015         2016  \
# 0     28334.0     28614.0  ...      50727.0      51185.0      51514.0
# ...

# %%
men.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
men.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis = 1 , inplace = True)

# %%
men.head()
# Out:
#                   Country Name        1960        1961        1962  \
# 0                        Aruba     26995.0     27326.0     27692.0
# 1  Africa Eastern and Southern  64409521.0  66120634.0  67916448.0
# 2                  Afghanistan   4690245.0   4775684.0   4867111.0
# 3   Africa Western and Central  48455513.0  49456062.0  50496568.0
# 4                       Angola   2649099.0   2690647.0   2721244.0
#
#          1963        1964        1965        1966        1967        1968  \
# 0     28027.0     28334.0     28614.0     28855.0     28999.0     29040.0
# 1  69778027.0  71729676.0  73764113.0  75854712.0  78035195.0  80320149.0
# 2   4963703.0   5065414.0   5173290.0   5285657.0   5402774.0   5525923.0
# 3  51587717.0  52711199.0  53877859.0  55091272.0  56338265.0  57634330.0
# 4   2752564.0   2784880.0   2818210.0   2852358.0   2887186.0   2922522.0
#
#    ...         2014         2015         2016         2017         2018  \
# ...

# %%
men.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   5.775269e+07  5.855560e+07  5.964521e+07  6.099604e+07  6.235917e+07
# std    1.821485e+08  1.844041e+08  1.877703e+08  1.921476e+08  1.965498e+08
# min    1.282000e+03  1.417000e+03  1.573000e+03  1.744000e+03  1.921000e+03
# 25%    2.481938e+05  2.529545e+05  2.579672e+05  2.634920e+05  2.817540e+05
# 50%    1.803844e+06  1.829865e+06  1.865790e+06  1.909102e+06  1.953728e+06
# 75%    1.351369e+07  1.387658e+07  1.425738e+07  1.464931e+07  1.501187e+07
# max    1.507700e+09  1.528387e+09  1.555961e+09  1.589728e+09  1.623748e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   6.373530e+07  6.516850e+07  6.660444e+07  6.807836e+07  6.960414e+07
# ...

# %%
men.isna().sum()
# Out:
# 1960    0
# 1961    0
# 1962    0
# 1963    0
# 1964    0
#        ..
# 2019    0
# 2020    0
# 2021    0
# 2022    0
# 2023    0
# Length: 64, dtype: int64

# %%
# Fill NaN values only in numeric columns
men = men.fillna(men.select_dtypes(include=['number']).mean())

# Convert only float columns to integer
men = men.astype({col: 'int' for col in men.select_dtypes('float').columns})
men.head()
# Out:
#                   Country Name      1960      1961      1962      1963  \
# 0                        Aruba     26995     27326     27692     28027
# 1  Africa Eastern and Southern  64409521  66120634  67916448  69778027
# 2                  Afghanistan   4690245   4775684   4867111   4963703
# 3   Africa Western and Central  48455513  49456062  50496568  51587717
# 4                       Angola   2649099   2690647   2721244   2752564
#
#        1964      1965      1966      1967      1968  ...       2014  \
# 0     28334     28614     28855     28999     29040  ...      50727
# 1  71729676  73764113  75854712  78035195  80320149  ...  291989157
# 2   5065414   5173290   5285657   5402774   5525923  ...   16570680
# 3  52711199  53877859  55091272  56338265  57634330  ...  204535979
# 4   2784880   2818210   2852358   2887186   2922522  ...   13409269
#
#         2015       2016       2017       2018       2019       2020  \
# ...

# %%
men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   1960          264 non-null    float64
#  2   1961          264 non-null    float64
#  3   1962          264 non-null    float64
#  4   1963          264 non-null    float64
#  5   1964          264 non-null    float64
#  6   1965          264 non-null    float64
#  7   1966          264 non-null    float64
#  8   1967          264 non-null    float64
#  9   1968          264 non-null    float64
#  10  1969          264 non-null    float64
#  11  1970          264 non-null    float64
#  12  1971          264 non-null    float64
#  13  1972          264 non-null    float64
#  14  1973          264 non-null    float64
#  15  1974          264 non-null    float64
#  16  1975          264 non-null    float64
# ...

# %%
women = pd.read_csv(r"C:\Users\gowth\Downloads\PRODIGY_internship\dataset\task 1\API_SP.POP.TOTL.FE.IN_DS2_en_CSV_v2_7318\women_population.csv")

# %%
women.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis = 1 , inplace = True)

# %%
women.columns
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %%
women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   1960          264 non-null    float64
#  2   1961          264 non-null    float64
#  3   1962          264 non-null    float64
#  4   1963          264 non-null    float64
#  5   1964          264 non-null    float64
#  6   1965          264 non-null    float64
#  7   1966          264 non-null    float64
#  8   1967          264 non-null    float64
#  9   1968          264 non-null    float64
#  10  1969          264 non-null    float64
#  11  1970          264 non-null    float64
#  12  1971          264 non-null    float64
#  13  1972          264 non-null    float64
#  14  1973          264 non-null    float64
#  15  1974          264 non-null    float64
#  16  1975          264 non-null    float64
# ...

# %%
women = women.fillna(women.select_dtypes(include=['number']).mean())

# Convert only float columns to integer
women = women.astype({col: 'int' for col in women.select_dtypes('float').columns})
women.head()
# Out:
#                   Country Name      1960      1961      1962      1963  \
# 0                        Aruba     27927     28252     28628     28975
# 1  Africa Eastern and Southern  65662559  67414289  69255211  71167509
# 2                  Afghanistan   4344798   4438399   4537295   4640784
# 3   Africa Western and Central  49175412  50250612  51358188  52501458
# 4                       Angola   2582555   2610936   2633066   2655756
#
#        1964      1965      1966      1967      1968  ...       2014  \
# 0     29285     29576     29839     29991     30029  ...      56080
# 1  73174418  75269359  77426491  79669186  82009247  ...  298979833
# 2   4748904   4862718   4980738   5103185   5230999  ...   16221843
# 3  53677241  54894773  56155681  57456754  58810306  ...  202456068
# 4   2679307   2703771   2729028   2754621   2780177  ...   13751500
#
#         2015       2016       2017       2018       2019       2020  \
# ...

# %%
year_sums = {}
for column in men.columns:
   year_sums[column] = men[column].sum()

# Convert the result into a DataFrame for visualization
df_sums = pd.DataFrame(list(year_sums.items()), columns=['Year', 'Sum'])

df_sums.head()
# Out:
#    Year                 Sum
# 0  1960  289133750502944816
# 1  1961  293153409053223936
# 2  1962  298608455685599752
# 3  1963  305371272114176856
# 4  1964  312195689124191544

# %%
# Plotting the line chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_sums, x='Year', y='Sum', marker='o', color='skyblue')

# Adding title and labels
plt.title('Sum of men Population by Year')
plt.xlabel('Year')
plt.ylabel('Sum of Population')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_sums, x='Year', y='Sum', palette='Blues_d')
plt.title('Sum of Men Population by Year')
plt.xlabel('Year')
plt.ylabel('Sum of Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gowth\AppData\Local\Temp\ipykernel_14324\3914223126.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_sums, x='Year', y='Sum', palette='Blues_d')

# %%
year_sums = {}
for column in men.columns:
   year_sums[column] = women[column].sum()

# Convert the result into a DataFrame for visualization
df_women_sums = pd.DataFrame(list(year_sums.items()), columns=['Year', 'Sum'])

df_women_sums.head(15)
# Out:
#     Year          Sum
# 0   1960  15346944483
# 1   1961  15560510939
# 2   1962  15845842757
# 3   1963  16197205472
# 4   1964  16551681292
# 5   1965  16911164425
# 6   1966  17287228889
# 7   1967  17664605082
# 8   1968  18051874045
# 9   1969  18451450125
# 10  1970  18859271074
# 11  1971  19276596189
# 12  1972  19684730386
# 13  1973  20097032258
# 14  1974  20508651699

# %%
df_women_sums.tail()
# Out:
#     Year          Sum
# 59  2019  15475236031
# 60  2020  15798663504
# 61  2021  16086315840
# 62  2022  16381015580
# 63  2023  16686359670

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data=df_women_sums, x='Year', y='Sum', marker='o', color='skyblue')

# Adding title and labels
plt.title('Sum of Women Population by Year')
plt.xlabel('Year')
plt.ylabel('Sum of Population')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_women_sums, x='Year', y='Sum', palette='Blues_d')
plt.title('Sum of Women Population by Year')
plt.xlabel('Year')
plt.ylabel('Sum of Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gowth\AppData\Local\Temp\ipykernel_14324\2759169566.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_women_sums, x='Year', y='Sum', palette='Blues_d')
